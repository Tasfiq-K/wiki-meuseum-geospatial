# %%
import pandas as pd
import numpy as np
import folium
import geopy
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
web_link = 'https://en.wikipedia.org/wiki/List_of_most-visited_museums'
df = pd.read_html(web_link)[0]
df.head()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                        Name Visitors in 2023 or 2022                City  \
# 0                    Louvre      8,700,000 (2024)[1]               Paris
# 1           Vatican Museums      6,800,000 (2023)[2]  Vatican City, Rome
# 2  National Museum of China      6,765,000 (2023)[3]             Beijing
# 3            British Museum      5,820,860 (2023)[4]              London
# 4    Natural History Museum      5,688,608 (2023)[5]              London
#
#           Country
# 0          France
# 1         Vatican
# 2           China
# 3  United Kingdom
# 4  United Kingdom

# %%
df.rename(columns={
    'Name': 'name',
    'Visitors in 2023 or 2022': 'visitors_count',
    'City': 'city',
    'Country': 'country',
}, inplace=True)

df.head()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                        name       visitors_count                city  \
# 0                    Louvre  8,700,000 (2024)[1]               Paris
# 1           Vatican Museums  6,800,000 (2023)[2]  Vatican City, Rome
# 2  National Museum of China  6,765,000 (2023)[3]             Beijing
# 3            British Museum  5,820,860 (2023)[4]              London
# 4    Natural History Museum  5,688,608 (2023)[5]              London
#
#           country
# 0          France
# 1         Vatican
# 2           China
# 3  United Kingdom
# 4  United Kingdom

# %%
# df['visitors_count'] =
df['total_visitors'] = df['visitors_count'].str.split(r'[\(\[]', n=1).str[0]
# df['total_visitors'] = df['total_visitors'].str.replace(',', '').astype(int)
# df.head()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def clean_visitors(value):
    # Remove extra spaces and handle None or NaN values
    if pd.isna(value):
        return np.nan
    value = value.strip()

    # Convert "3.8 million" or similar to integer
    if 'million' in value.lower():
        try:
            return int(float(value.lower().replace('million', '').strip()) * 1_000_000)
        except ValueError:
            return np.nan

    # Replace dots and commas appropriately and convert to integer
    try:
        value = value.replace('.', '').replace(',', '')
        return int(value)
    except ValueError:
        return np.nan

# Apply cleaning function to the column
df['total_visitors_cleaned'] = df['total_visitors'].apply(clean_visitors)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
df.dropna(subset=['total_visitors_cleaned'], inplace=True)
df['total_visitors_cleaned'] = df['total_visitors_cleaned'].astype(int)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
df.head()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                        name       visitors_count                city  \
# 0                    Louvre  8,700,000 (2024)[1]               Paris
# 1           Vatican Museums  6,800,000 (2023)[2]  Vatican City, Rome
# 2  National Museum of China  6,765,000 (2023)[3]             Beijing
# 3            British Museum  5,820,860 (2023)[4]              London
# 4    Natural History Museum  5,688,608 (2023)[5]              London
#
#           country total_visitors  total_visitors_cleaned
# 0          France     8,700,000                  8700000
# 1         Vatican     6,800,000                  6800000
# 2           China     6,765,000                  6765000
# 3  United Kingdom     5,820,860                  5820860
# 4  United Kingdom     5,688,608                  5688608

# %%
# Initiate the nominatim geocoder
geolocator = Nominatim(user_agent = 'monument_geocoder')
# Create a rate limiter
geocode = RateLimiter(geolocator.geocode, min_delay_seconds = 2)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
df['Full address'] = 0
df['Latitude'] = 0
df['Longitude'] = 0

for index, row in df.iterrows():
  # print(row['address_1'])
  addr = f"{row['name']}, {row['city']}, {row['country']}"
  location_info = geocode(addr)

  try:

    # saving the address, lat, lon information into the corresponding variables during each iteration
    full_addres = location_info.address
    lat = location_info.latitude
    lon = location_info.longitude

    df.loc[index, 'Full address' ] = full_addres
    df.loc[index, 'Latitude' ] = lat
    df.loc[index, 'Longitude' ] = lon

    print(f'We have gotten the data for {full_addres}')

  except AttributeError:
    df.loc[index, 'Full address' ] = 'No Info'
    df.loc[index, 'Latitude' ] = 'No Info'
    df.loc[index, 'Longitude' ] = 'No Info'

# %%
df[df['Full address'].str.contains('No Info', na = False)]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                                                  name          visitors_count  \
# 1                                     Vatican Museums     6,800,000 (2023)[2]
# 16                Musée National d'Histoire Naturelle  3.8 million (2023)[17]
# 19                      Palace and Garden of Sa'dabad    3,121,000 (2022)[20]
# 21                   National Air and Space Museum[a]    3,100,000 (2023)[22]
# 24                    National Museum of Anthropology        2,636,352 (2023)
# 28             Smithsonian Museum of American History    2,100,000 (2023)[27]
# 32                               State Russian Museum    2,900,000 (2023)[31]
# 33   National Museum of Marine Science and Technology    2,726,000 (2023)[32]
# 34                              London Science Museum   2,957,000 (2023) [33]
# 36                            Chinese Aviation Museum    2,300,000 (2022)[35]
# 48                            Royal Museums Greenwich           1,628,580[47]
# 49                 Zhejiang Museum of Natural History           1,581,263[48]
# 64                           Louis Vuitton Foundation    1,500,000 (2023)[56]
# 72                     Tianjin Natural History Museum           1,320,752[59]
# 74  Museum of European and Mediterranean Civilisat...        1,300,000 (2023)
#
#                   city         country total_visitors  total_visitors_cleaned  \
# 1   Vatican City, Rome         Vatican     6,800,000                  6800000
# 16               Paris          France   3.8 million                  3800000
# 19              Tehran            Iran     3,121,000                  3121000
# 21    Washington, D.C.   United States     3,100,000                  3100000
# 24         Mexico City          Mexico     2,636,352                  2636352
# 28    Washington, D.C.   United States     2,100,000                  2100000
# 32    Saint Petersburg          Russia     2,900,000                  2900000
# 33             Keelung          Taiwan     2,726,000                  2726000
# 34              London  United Kingdom     2,957,000                  2957000
# 36             Beijing           China     2,300,000                  2300000
# 48              London  United Kingdom      1,628,580                 1628580
# 49            Hangzhou           China      1,581,263                 1581263
# 64               Paris          France     1,500,000                  1500000
# 72             Tianjin           China      1,320,752                 1320752
# 74           Marseille          France     1,300,000                  1300000
#
#     latitude  longitude full_address Full address Latitude Longitude
# 1        NaN        NaN          NaN      No Info  No Info   No Info
# 16       NaN        NaN          NaN      No Info  No Info   No Info
# 19       NaN        NaN          NaN      No Info  No Info   No Info
# 21       NaN        NaN          NaN      No Info  No Info   No Info
# 24       NaN        NaN          NaN      No Info  No Info   No Info
# 28       NaN        NaN          NaN      No Info  No Info   No Info
# 32       NaN        NaN          NaN      No Info  No Info   No Info
# 33       NaN        NaN          NaN      No Info  No Info   No Info
# 34       NaN        NaN          NaN      No Info  No Info   No Info
# 36       NaN        NaN          NaN      No Info  No Info   No Info
# 48       NaN        NaN          NaN      No Info  No Info   No Info
# 49       NaN        NaN          NaN      No Info  No Info   No Info
# 64       NaN        NaN          NaN      No Info  No Info   No Info
# 72       NaN        NaN          NaN      No Info  No Info   No Info
# 74       NaN        NaN          NaN      No Info  No Info   No Info

# %%
df = df[~df['Full address'].str.contains('No Info', na = False)]
df
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                                      name        visitors_count  \
# 0                                  Louvre   8,700,000 (2024)[1]
# 2                National Museum of China   6,765,000 (2023)[3]
# 3                          British Museum   5,820,860 (2023)[4]
# 4                  Natural History Museum   5,688,608 (2023)[5]
# 5              Metropolitan Museum of Art   5,400,000 (2023)[6]
# ..                                    ...                   ...
# 71  Museo Nazionale di Castel Sant'Angelo         1,321,834[58]
# 73          Palacio de Cristal del Retiro      1,318,823[b][41]
# 75              Scottish National Gallery         1,277,230[41]
# 76                      Museo Reina Sofía      1,253,183[c][41]
# 77                           Galata Tower  1,250,000 (2023)[60]
#
#              city         country total_visitors  total_visitors_cleaned  \
# 0           Paris          France     8,700,000                  8700000
# 2         Beijing           China     6,765,000                  6765000
# 3          London  United Kingdom     5,820,860                  5820860
# 4          London  United Kingdom     5,688,608                  5688608
# 5   New York City   United States     5,400,000                  5400000
# ..            ...             ...            ...                     ...
# 71           Rome           Italy      1,321,834                 1321834
# 73         Madrid           Spain      1,318,823                 1318823
# 75      Edinburgh  United Kingdom      1,277,230                 1277230
# 76         Madrid           Spain      1,253,183                 1253183
# 77       Istanbul          Turkey     1,250,000                  1250000
#
#      latitude  longitude                                       full_address  \
# 0   48.861147   2.338028  Musée du Louvre, Cour Carrée, Quartier Saint-G...
# 2         NaN        NaN                                                NaN
# 3         NaN        NaN                                                NaN
# 4         NaN        NaN                                                NaN
# 5         NaN        NaN                                                NaN
# ..        ...        ...                                                ...
# 71        NaN        NaN                                                NaN
# 73        NaN        NaN                                                NaN
# 75        NaN        NaN                                                NaN
# 76        NaN        NaN                                                NaN
# 77        NaN        NaN                                                NaN
#
#                                          Full address   Latitude  Longitude
# 0   Musée du Louvre, Cour Carrée, Quartier Saint-G...  48.861147   2.338028
# 2   中国国家博物馆, 16, 东长安街, 东华门街道, 首都功能核心区, 东城区, 北京市, 1...  39.903746  116.39539
# 3   British Museum, Great Russell Street, Saint Gi...  51.519294  -0.128018
# 4   Natural History Museum, Cromwell Road, Brompto...  51.496511  -0.176002
# 5   The Metropolitan Museum of Art, 1000, 5th Aven...   40.77944 -73.963382
# ..                                                ...        ...        ...
# 71  Museo Nazionale di Castel Sant’Angelo, 50, Lun...   41.90308  12.466181
# 73  Invernadero del Palacio de Cristal de Arganzue...  40.393491  -3.700241
# 75  National Gallery, The Mound, Old Town, City of...  55.950881  -3.195619
# 76  Museo Nacional Centro de Arte Reina Sofía, 52,...   40.40805  -3.694422
# 77  Galata Kulesi, Büyük Hendek Caddesi, Kuledibi,...  41.025641  28.974213
#
# [62 rows x 12 columns]

# %%
df.drop('full_address', axis=1, inplace=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
import folium
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# initiate a folium map
idx = 0
m = folium.Map(location = [df.loc[idx, 'Latitude'], df.loc[idx, 'Longitude']], zoom_start = 10)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
for index, row in df.iterrows():

  # Info to display in popup
  popup_info = f"""
  Name: {row['name']}<br><br>
  Full Address: {row['Full address']}<br><br>
  Latitude: {row['Latitude']}<br><br>
  Longitude: {row['Longitude']}
  """

  # Creating a marker
  folium.Marker(
      location = [row['Latitude'], row['Longitude']],
      popup = folium.Popup(popup_info, max_width = 300)
  ).add_to(m)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ee9d3f735a549e9afae8d1130399a100 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ee9d3f735a549e9afae8d1130399a100&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ee9d3f735a549e9afae8d1130399a100 = L.map(
#                 &quot;map_ee9d3f735a549e9afae8d1130399a100&quot;,
#                 {
#                     center: [48.8611473, 2.33802768704666],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_15b9086ed7031418143854b292bd867e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_15b9086ed7031418143854b292bd867e.addTo(map_ee9d3f735a549e9afae8d1130399a100);
#
#
#             var marker_fcfdd8224fccdf687c2ecd06ebeaaddb = L.marker(
#                 [48.8611473, 2.33802768704666],
#                 {
# }
#             ).addTo(map_ee9d3f735a549e9afae8d1130399a100);
#
#
#         var popup_860defe9ff85ed27f7659e3e8dc2b356 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_9f4c56ee3a6419e038634dc99ceef410 = $(`&lt;div id=&quot;html_9f4c56ee3a6419e038634dc99ceef410&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;   Name: Louvre&lt;br&gt;&lt;br&gt;   Full Address: Musée du Louvre, Cour Carrée, Quartier Saint-Germain-l&#x27;Auxerrois, Paris 1er Arrondissement, Paris, Île-de-France, France métropolitaine, 75001, France&lt;br&gt;&lt;br&gt;   Latitude: 48.8611473&lt;br&gt;&lt;br&gt;   Longitude: 2.33802768704666   &lt;/div&gt;`)[0];
#                 popup_860defe9ff85ed27f7659e3e8dc2b356.setContent(html_9f4c56ee3a6419e038634dc99ceef410);
#
#
#
#         marker_fcfdd8224fccdf687c2ecd06ebeaaddb.bindPopup(popup_860defe9ff85ed27f7659e3e8dc2b356)
#         ;
#
#
#
#
#             var marker_c97a958fc9466a5ed2f3694780f0cadf = L.marker(
#                 [39.903745900000004, 116.39538964666366],
#                 {
# }
#             ).addTo(map_ee9d3f735a549e9afae8d1130399a100);
#
#
#         var popup_4a412ec09b8a3de0d7c001f3eed631d3 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_791be6e86994d374b85c749e07d66c15 = $(`&lt;div id=&quot;html_791be6e86994d374b85c749e07d66c15&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;   Name: National Museum of China&lt;br&gt;&lt;br&gt;   Full Address: 中国国家博物馆, 16, 东长安街, 东华门街道, 首都功能核心区, 东城区, 北京市, 100006, 中国&lt;br&gt;&lt;br&gt;   Latitude: 39.903745900000004&lt;br&gt;&lt;br&gt;   Longitude: 116.39538964666366   &lt;/div&gt;`)[0];
#                 popup_4a412ec09b8a3de0d7c001f3eed631d3.setContent(html_791be6e86994d374b85c749e07d66c15);
#
#
#
#         marker_c97a958fc9466a5ed2f3694780f0cadf.bindPopup(popup_4a412ec09b8a3de0d7c001f3eed631d3)
#         ;
#
#
#
#
#             var marker_2956b6d52172f9ebbdf910710f1b4574 = L.marker(
#                 [51.51929365, -0.12801772178494725],
#                 {
# }
#             ).addTo(map_ee9d3f735a549e9afae8d1130399a100);
#
#
#         var popup_7911a6b3c77de7dd07ad3641998faecd = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_7e4c0a894e655ccf049b5eb074487213 = $(`&lt;div id=&quot;html_7e4c0a894e655ccf049b5eb074487213&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;   Name: British Museum&lt;br&gt;&lt;br&gt;   Full Address: British Museum, Great Russell Street, Saint Giles, Bloomsbury, London Borough of Camden, London, Greater London, England, WC1B 3DG, United Kingdom&lt;br&gt;&lt;br&gt;   Latitude: 51.51929365&lt;br&gt;&lt;br&gt;   Longitude: -0.12801772178494725   &lt;/div&gt;`)[0];
#                 popup_7911a6b3c77de7dd07ad3641998faecd.setContent(html_7e4c0a894e655ccf049b5eb074487213);
#
#
#
#         marker_2956b6d52172f9ebbdf910710f1b4574.bindPopup(popup_7911a6b3c77de7dd07ad3641998faecd)
#         ;
#
#
#
#
#             var marker_7c42076302bee602dbc39c7d0fab601d = L.marker(
#                 [51.496510900000004, -0.17600190725447445],
#                 {
# }
#             ).addTo(map_ee9d3f735a549e9afae8d1130399a100);
#
#
#         var popup_feb0213a5614ea33f968724eafd37cd5 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_68258da936b22d52f01a2ea120463917 = $(`&lt;div id=&quot;html_68258da936b22d52f01a2ea120463917&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;   Name: Natural History Museum&lt;br&gt;&lt;br&gt;   Full Address: Natural History Museum, Cromwell Road, Brompton, Royal Borough of Kensington and Chelsea, London, Greater London, England, SW7 5BD, United Kingdom&lt;br&gt;&lt;br&gt;   Latitude: 51.496510900000004&lt;br&gt;&lt;br&gt;   Longitude: -0.17600190725447445   &lt;/div&gt;`)[0];
#                 popup_feb0213a5614ea33f968724eafd37c
